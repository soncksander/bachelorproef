# %%
import pandas as pd

# %%
df = pd.read_json("../data/transformed_recipes.ndjson",lines=True)
df.head()
# Out:
#                                                title  \
# 0  Miso-Butter Roast Chicken With Acorn Squash Pa...
# 1                    Crispy Salt and Pepper Potatoes
# 2                        Thanksgiving Mac and Cheese
# 3                 Italian Sausage and Bread Stuffing
# 4                                       Newton's Law
#
#                                          ingredients  \
# 0  [1.6–1.8 kg whole chicken, 7.7 g kosher salt, ...
# 1  [2 large egg whites, 450 g new potatoes, 2.5 c...
# 2  [240 ml evaporated milk, 240 ml whole milk, 2....
# 3  [Round Italian loaf, 340–454 g, cut into 2.5 c...
# 4  [4.3 g dark brown sugar, 5 ml hot water, 44 ml...
#
#                                         instructions
# 0  Pat chicken dry with paper towels, season all ...
# 1  Preheat oven to 204 °C and line a rimmed bakin...
# 2  Place rack in middle of oven; preheat to 205°C...
# 3  Preheat oven to 177°C with rack in the middle....
# 4  Stir together dark brown sugar and hot water i...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         97 non-null     object
#  1   ingredients   97 non-null     object
#  2   instructions  97 non-null     object
# dtypes: object(3)
# memory usage: 2.4+ KB
